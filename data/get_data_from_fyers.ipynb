# %% [markdown]
# ## Methodology

# %%
# from fyers_apiv3 import fyersModel
# import webbrowser

# """
# In order to get started with Fyers API we would like you to do the following things first.
# 1. Checkout our API docs :   https://myapi.fyers.in/docsv3
# 2. Create an APP using our API dashboard :   https://myapi.fyers.in/dashboard/

# Once you have created an APP you can start using the below SDK 
# """

# #### Generate an authcode and then make a request to generate an accessToken (Login Flow)

# """
# 1. Input parameters
# """
# redirect_uri= "APP REDIRECT URI"  ## redircet_uri you entered while creating APP.
# client_id = "XCXXXXXxxM-100"                       ## Client_id here refers to APP_ID of the created app
# secret_key = "MH*****TJ5"                          ## app_secret key which you got after creating the app 
# grant_type = "authorization_code"                  ## The grant_type always has to be "authorization_code"
# response_type = "code"                             ## The response_type always has to be "code"
# state = "sample"                                   ##  The state field here acts as a session manager. you will be sent with the state field after successfull generation of auth_code 


# ### Connect to the sessionModel object here with the required input parameters
# appSession = fyersModel.SessionModel(client_id = client_id, redirect_uri = redirect_uri,response_type=response_type,state=state,secret_key=secret_key,grant_type=grant_type)

# # ## Make  a request to generate_authcode object this will return a login url which you need to open in your browser from where you can get the generated auth_code 
# generateTokenUrl = appSession.generate_authcode()

# """There are two method to get the Login url if  you are not automating the login flow
# 1. Just by printing the variable name 
# 2. There is a library named as webbrowser which will then open the url for you without the hasel of copy pasting
# both the methods are mentioned below"""
# print((generateTokenUrl))  
# webbrowser.open(generateTokenUrl,new=1)

# """
# run the code firstly upto this after you generate the auth_code comment the above code and start executing the below code """
# ##########################################################################################################################

# ### After succesfull login the user can copy the generated auth_code over here and make the request to generate the accessToken 
# auth_code = "Paste the auth_code generated from the first request"
# appSession.set_token(auth_code)
# response = appSession.generate_token()

# ## There can be two cases over here you can successfully get the acccessToken over the request or you might get some error over here. so to avoid that have this in try except block
# try: 
#     access_token = response["access_token"]
# except Exception as e:
#     print(e,response)  ## This will help you in debugging then and there itself like what was the error and also you would be able to see the value you got in response variable. instead of getting key_error for unsuccessfull response.



# ## Once you have generated accessToken now we can call multiple trading related or data related apis after that in order to do so we need to first initialize the fyerModel object with all the requried params.
# """
# fyerModel object takes following values as arguments
# 1. accessToken : this is the one which you received from above 
# 2. client_id : this is basically the app_id for the particular app you logged into
# """
# fyers = fyersModel.FyersModel(token=access_token,is_async=False,client_id=client_id,log_path="")

# %% [markdown]
# ## Generate Token

# %%
from fyers_apiv3 import fyersModel
from fyers_apiv3.FyersWebsocket import data_ws

import webbrowser

# %%
secret_key = "0UT0LW5PE4"
client_id = "ALT6RUE1IF-100"
redirect_uri = "https://luvratan.tech/"

# %%
appSession = fyersModel.SessionModel(client_id = client_id, redirect_uri = redirect_uri,response_type="code",state="sample",secret_key=secret_key,grant_type="authorization_code")

# %%
generateTokenUrl = appSession.generate_authcode()

# %%
webbrowser.open(generateTokenUrl,new=1)
# Out:
# True

# %%
token ="https://luvratan.tech/?s=ok&code=200&auth_code=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....X1FdEkn016_ctuATyCUwQhkIV8F8EiNTj5ckwCTSxXQ&state=sample"

# %%
access_token = token.split("auth_code=")[1].split("&state")[0]

# %%
# auth_code = generateTokenUrl
appSession.set_token(access_token)
response = appSession.generate_token()

# %%
## There can be two cases over here you can successfully get the acccessToken over the request or you might get some error over here. so to avoid that have this in try except block
try: 
    access_token = response["access_token"]
except Exception as e:
    print(e,response)  ## This will help you in debugging then and there itself like what was the error and also you would be able to see the value you got in response variable. instead of getting key_error for unsuccessfull response.

# %% [markdown]
# ### Get Data

# %%
fyers = fyersModel.FyersModel(token=access_token,is_async=False,client_id=client_id,log_path="")

# %%
## Historical Data 

data = {"symbol":"NSE:SBIN-EQ","resolution":"D","date_format":"0","range_from":"1622097600","range_to":"1622097685","cont_flag":"1"}

print(fyers.history(data))

## Quotes 

data = {"symbols":"NSE:SBIN-EQ"}
print(fyers.quotes(data))


## Market Depth 

data = {"symbol":"NSE:SBIN-EQ","ohlcv_flag":"1"}
print(fyers.depth(data))
# Out:
# {'candles': [[1622073600, 413.7, 429.1, 412, 425.2, 73392997]], 'code': 200, 'message': '', 's': 'ok'}
# {'s': 'error', 'code': 429, 'message': 'Bad request'}
# {'d': {'NSE:SBIN-EQ': {'totalbuyqty': 4016, 'totalsellqty': 0, 'ask': [{'price': 0, 'volume': 0, 'ord': 0}, {'price': 0, 'volume': 0, 'ord': 0}, {'price': 0, 'volume': 0, 'ord': 0}, {'price': 0, 'volume': 0, 'ord': 0}, {'price': 0, 'volume': 0, 'ord': 0}], 'bids': [{'price': 948.1, 'volume': 4016, 'ord': 26}, {'price': 0, 'volume': 0, 'ord': 0}, {'price': 0, 'volume': 0, 'ord': 0}, {'price': 0, 'volume': 0, 'ord': 0}, {'price': 0, 'volume': 0, 'ord': 0}], 'o': 951.05, 'h': 952.55, 'l': 944.45, 'c': 951.05, 'chp': -0.31, 'tick_Size': 0.05, 'ch': -2.95, 'ltq': 250, 'ltt': 1764844054, 'ltp': 948.1, 'v': 13622724, 'atp': 947.46, 'lower_ckt': 853.3, 'upper_ckt': 1042.9, 'expiry': '', 'oi': 0, 'oiflag': False, 'pdoi': 0, 'oipercent': 0}}, 'message': 'Success', 's': 'ok'}

# %% [markdown]
# ### Monthly Data API

# %%
# import os
# import calendar
# from datetime import datetime, timedelta
# import pandas as pd

# # --- Convert Python datetime → UNIX epoch ---
# def to_epoch(dt):
#     return int(dt.timestamp())


# # --- Fetch data from FYERS ---
# def fetch_fyers_candles(fyers, symbol, start_epoch, end_epoch, resolution):
#     data = {
#         "symbol": symbol,
#         "resolution": str(resolution),
#         "date_format": "0",
#         "range_from": str(start_epoch),
#         "range_to": str(end_epoch),
#         "cont_flag": "1"
#     }
#     return fyers.history(data)


# # --- Save JSON → CSV ---
# def save_to_csv(json_data, filepath):
#     candles = json_data.get("candles", [])
#     if len(candles) == 0:
#         print(f"No data: {filepath}")
#         return

#     df = pd.DataFrame(
#         candles,
#         columns=["timestamp", "open", "high", "low", "close", "volume"]
#     )

#     # Convert UTC timestamp to IST
#     df["datetime"] = (
#         pd.to_datetime(df["timestamp"], unit="s", utc=True)
#             .dt.tz_convert("Asia/Kolkata")
#     )
#     df["datetime"] = df["datetime"] + pd.Timedelta(minutes=5)

#     # Reorder columns
#     df = df[["datetime", "timestamp", "open", "high", "low", "close", "volume"]]

#     df.to_csv(filepath, index=False)
#     print(f"Saved: {filepath}")



# def fetch_monthly_data(fyers, symbol, resolution="5"):
#     # -----------------------------
#     # Extract a clean symbol name
#     # Example: "NSE:SBIN-EQ" → "sbin_eq"
#     # -----------------------------
#     symbol_name = symbol.split(":")[1].replace("-", "_").replace(".", "_").lower()

#     # Folder path
#     save_folder = f"5_min_data/{symbol_name}"
#     os.makedirs(save_folder, exist_ok=True)

#     # Date range
#     start_year, start_month = 2024, 12
#     end_year, end_month = 2025, 11

#     year, month = start_year, start_month

#     while (year < end_year) or (year == end_year and month <= end_month):

#         # 1st day of month
#         start_dt = datetime(year, month, 1, 0, 0, 0)

#         # Last day of month
#         last_day = calendar.monthrange(year, month)[1]
#         end_dt = datetime(year, month, last_day, 23, 59, 59)

#         # Convert datetime → epoch
#         start_epoch = to_epoch(start_dt)
#         end_epoch = to_epoch(end_dt)

#         print(f"\nFetching {symbol}: {start_dt.date()} → {end_dt.date()}")

#         # Fetch from FYERS
#         json_data = fetch_fyers_candles(
#             fyers=fyers,
#             symbol=symbol,
#             start_epoch=start_epoch,
#             end_epoch=end_epoch,
#             resolution=resolution
#         )

#         # CSV filename → {symbol}_{year}_{month}.csv
#         filename = f"{symbol_name}_{year}_{str(month).zfill(2)}.csv"
#         filepath = os.path.join(save_folder, filename)

#         save_to_csv(json_data, filepath)

#         # Increment month
#         if month == 12:
#             month = 1
#             year += 1
#         else:
#             month += 1

# # -----------------------------
# # Run the monthly data fetcher
# # -----------------------------
# fetch_monthly_data(fyers, "NSE:NIFTY50-INDEX", resolution="5")
# Out:
# Fetching NSE:NIFTY50-INDEX: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/nifty50_index\nifty50_index_2024_12.csv
#
# Fetching NSE:NIFTY50-INDEX: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/nifty50_index\nifty50_index_2025_01.csv
#
# Fetching NSE:NIFTY50-INDEX: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/nifty50_index\nifty50_index_2025_02.csv
#
# Fetching NSE:NIFTY50-INDEX: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/nifty50_index\nifty50_index_2025_03.csv
#
# Fetching NSE:NIFTY50-INDEX: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/nifty50_index\nifty50_index_2025_04.csv
#
# Fetching NSE:NIFTY50-INDEX: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/nifty50_index\nifty50_index_2025_05.csv
#
# Fetching NSE:NIFTY50-INDEX: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/nifty50_index\nifty50_index_2025_06.csv
#
# Fetching NSE:NIFTY50-INDEX: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/nifty50_index\nifty50_index_2025_07.csv
#
# Fetching NSE:NIFTY50-INDEX: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/nifty50_index\nifty50_index_2025_08.csv
#
# Fetching NSE:NIFTY50-INDEX: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/nifty50_index\nifty50_index_2025_09.csv
#
# Fetching NSE:NIFTY50-INDEX: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/nifty50_index\nifty50_index_2025_10.csv
#
# Fetching NSE:NIFTY50-INDEX: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/nifty50_index\nifty50_index_2025_11.csv

# %%
nifty50_tickers = [
    "NSE:ADANIENT-EQ",
    "NSE:ADANIPORTS-EQ",
    "NSE:APOLLOHOSP-EQ",
    "NSE:ASIANPAINT-EQ",
    "NSE:AXISBANK-EQ",
    "NSE:BAJAJ-AUTO-EQ",
    "NSE:BAJFINANCE-EQ",
    "NSE:BAJAJFINSV-EQ",
    "NSE:BPCL-EQ",
    "NSE:BHARTIARTL-EQ",
    "NSE:BRITANNIA-EQ",
    "NSE:CIPLA-EQ",
    "NSE:COALINDIA-EQ",
    "NSE:DIVISLAB-EQ",
    "NSE:DRREDDY-EQ",
    "NSE:EICHERMOT-EQ",
    "NSE:GRASIM-EQ",
    "NSE:HCLTECH-EQ",
    "NSE:HDFCBANK-EQ",
    "NSE:HDFCLIFE-EQ",
    "NSE:HEROMOTOCO-EQ",
    "NSE:HINDALCO-EQ",
    "NSE:HINDUNILVR-EQ",
    "NSE:ICICIBANK-EQ",
    "NSE:ITC-EQ",
    "NSE:INDUSINDBK-EQ",
    "NSE:INFY-EQ",
    "NSE:JSWSTEEL-EQ",
    "NSE:KOTAKBANK-EQ",
    "NSE:LT-EQ",
    "NSE:M&M-EQ",
    "NSE:MARUTI-EQ",
    "NSE:NTPC-EQ",
    "NSE:NESTLEIND-EQ",
    "NSE:ONGC-EQ",
    "NSE:POWERGRID-EQ",
    "NSE:RELIANCE-EQ",
    "NSE:SBILIFE-EQ",
    "NSE:SHRIRAMFIN-EQ",
    "NSE:SBIN-EQ",
    "NSE:SUNPHARMA-EQ",
    "NSE:TCS-EQ",
    "NSE:TATACONSUM-EQ",
    "NSE:TATAMOTORS-EQ",
    "NSE:TATASTEEL-EQ",
    "NSE:TECHM-EQ",
    "NSE:TITAN-EQ",
    "NSE:ULTRACEMCO-EQ",
    "NSE:WIPRO-EQ",
    "NSE:ZOMATO-EQ"
]

# %%
# for symbol in nifty50_tickers:
#     fetch_monthly_data(fyers, symbol, resolution="5")
# Out:
# Fetching NSE:ADANIENT-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/adanient_eq\adanient_eq_2024_12.csv
#
# Fetching NSE:ADANIENT-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/adanient_eq\adanient_eq_2025_01.csv
#
# Fetching NSE:ADANIENT-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/adanient_eq\adanient_eq_2025_02.csv
#
# Fetching NSE:ADANIENT-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/adanient_eq\adanient_eq_2025_03.csv
#
# Fetching NSE:ADANIENT-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/adanient_eq\adanient_eq_2025_04.csv
#
# Fetching NSE:ADANIENT-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/adanient_eq\adanient_eq_2025_05.csv
#
# Fetching NSE:ADANIENT-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/adanient_eq\adanient_eq_2025_06.csv
#
# Fetching NSE:ADANIENT-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/adanient_eq\adanient_eq_2025_07.csv
#
# Fetching NSE:ADANIENT-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/adanient_eq\adanient_eq_2025_08.csv
#
# Fetching NSE:ADANIENT-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/adanient_eq\adanient_eq_2025_09.csv
#
# Fetching NSE:ADANIENT-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/adanient_eq\adanient_eq_2025_10.csv
#
# Fetching NSE:ADANIENT-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/adanient_eq\adanient_eq_2025_11.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2024_12.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2025_01.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2025_02.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2025_03.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2025_04.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2025_05.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2025_06.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2025_07.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2025_08.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2025_09.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2025_10.csv
#
# Fetching NSE:ADANIPORTS-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/adaniports_eq\adaniports_eq_2025_11.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2024_12.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2025_01.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2025_02.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2025_03.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2025_04.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2025_05.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2025_06.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2025_07.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2025_08.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2025_09.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2025_10.csv
#
# Fetching NSE:APOLLOHOSP-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/apollohosp_eq\apollohosp_eq_2025_11.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2024_12.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2025_01.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2025_02.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2025_03.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2025_04.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2025_05.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2025_06.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2025_07.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2025_08.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2025_09.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2025_10.csv
#
# Fetching NSE:ASIANPAINT-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/asianpaint_eq\asianpaint_eq_2025_11.csv
#
# Fetching NSE:AXISBANK-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2024_12.csv
#
# Fetching NSE:AXISBANK-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2025_01.csv
#
# Fetching NSE:AXISBANK-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2025_02.csv
#
# Fetching NSE:AXISBANK-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2025_03.csv
#
# Fetching NSE:AXISBANK-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2025_04.csv
#
# Fetching NSE:AXISBANK-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2025_05.csv
#
# Fetching NSE:AXISBANK-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2025_06.csv
#
# Fetching NSE:AXISBANK-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2025_07.csv
#
# Fetching NSE:AXISBANK-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2025_08.csv
#
# Fetching NSE:AXISBANK-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2025_09.csv
#
# Fetching NSE:AXISBANK-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2025_10.csv
#
# Fetching NSE:AXISBANK-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/axisbank_eq\axisbank_eq_2025_11.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2024_12.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2025_01.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2025_02.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2025_03.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2025_04.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2025_05.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2025_06.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2025_07.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2025_08.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2025_09.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2025_10.csv
#
# Fetching NSE:BAJAJ-AUTO-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/bajaj_auto_eq\bajaj_auto_eq_2025_11.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2024_12.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2025_01.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2025_02.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2025_03.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2025_04.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2025_05.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2025_06.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2025_07.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2025_08.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2025_09.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2025_10.csv
#
# Fetching NSE:BAJFINANCE-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/bajfinance_eq\bajfinance_eq_2025_11.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2024_12.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2025_01.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2025_02.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2025_03.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2025_04.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2025_05.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2025_06.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2025_07.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2025_08.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2025_09.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2025_10.csv
#
# Fetching NSE:BAJAJFINSV-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/bajajfinsv_eq\bajajfinsv_eq_2025_11.csv
#
# Fetching NSE:BPCL-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2024_12.csv
#
# Fetching NSE:BPCL-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2025_01.csv
#
# Fetching NSE:BPCL-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2025_02.csv
#
# Fetching NSE:BPCL-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2025_03.csv
#
# Fetching NSE:BPCL-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2025_04.csv
#
# Fetching NSE:BPCL-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2025_05.csv
#
# Fetching NSE:BPCL-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2025_06.csv
#
# Fetching NSE:BPCL-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2025_07.csv
#
# Fetching NSE:BPCL-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2025_08.csv
#
# Fetching NSE:BPCL-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2025_09.csv
#
# Fetching NSE:BPCL-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2025_10.csv
#
# Fetching NSE:BPCL-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/bpcl_eq\bpcl_eq_2025_11.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2024_12.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2025_01.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2025_02.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2025_03.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2025_04.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2025_05.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2025_06.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2025_07.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2025_08.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2025_09.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2025_10.csv
#
# Fetching NSE:BHARTIARTL-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/bhartiartl_eq\bhartiartl_eq_2025_11.csv
#
# Fetching NSE:BRITANNIA-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/britannia_eq\britannia_eq_2024_12.csv
#
# Fetching NSE:BRITANNIA-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/britannia_eq\britannia_eq_2025_01.csv
#
# Fetching NSE:BRITANNIA-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/britannia_eq\britannia_eq_2025_02.csv
#
# Fetching NSE:BRITANNIA-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/britannia_eq\britannia_eq_2025_03.csv
#
# Fetching NSE:BRITANNIA-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/britannia_eq\britannia_eq_2025_04.csv
#
# Fetching NSE:BRITANNIA-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/britannia_eq\britannia_eq_2025_05.csv
#
# Fetching NSE:BRITANNIA-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/britannia_eq\britannia_eq_2025_06.csv
#
# Fetching NSE:BRITANNIA-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/britannia_eq\britannia_eq_2025_07.csv
#
# Fetching NSE:BRITANNIA-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/britannia_eq\britannia_eq_2025_08.csv
#
# Fetching NSE:BRITANNIA-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/britannia_eq\britannia_eq_2025_09.csv
#
# Fetching NSE:BRITANNIA-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/britannia_eq\britannia_eq_2025_10.csv
#
# Fetching NSE:BRITANNIA-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/britannia_eq\britannia_eq_2025_11.csv
#
# Fetching NSE:CIPLA-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/cipla_eq\cipla_eq_2024_12.csv
#
# Fetching NSE:CIPLA-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/cipla_eq\cipla_eq_2025_01.csv
#
# Fetching NSE:CIPLA-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/cipla_eq\cipla_eq_2025_02.csv
#
# Fetching NSE:CIPLA-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/cipla_eq\cipla_eq_2025_03.csv
#
# Fetching NSE:CIPLA-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/cipla_eq\cipla_eq_2025_04.csv
#
# Fetching NSE:CIPLA-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/cipla_eq\cipla_eq_2025_05.csv
#
# Fetching NSE:CIPLA-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/cipla_eq\cipla_eq_2025_06.csv
#
# Fetching NSE:CIPLA-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/cipla_eq\cipla_eq_2025_07.csv
#
# Fetching NSE:CIPLA-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/cipla_eq\cipla_eq_2025_08.csv
#
# Fetching NSE:CIPLA-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/cipla_eq\cipla_eq_2025_09.csv
#
# Fetching NSE:CIPLA-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/cipla_eq\cipla_eq_2025_10.csv
#
# Fetching NSE:CIPLA-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/cipla_eq\cipla_eq_2025_11.csv
#
# Fetching NSE:COALINDIA-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2024_12.csv
#
# Fetching NSE:COALINDIA-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2025_01.csv
#
# Fetching NSE:COALINDIA-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2025_02.csv
#
# Fetching NSE:COALINDIA-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2025_03.csv
#
# Fetching NSE:COALINDIA-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2025_04.csv
#
# Fetching NSE:COALINDIA-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2025_05.csv
#
# Fetching NSE:COALINDIA-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2025_06.csv
#
# Fetching NSE:COALINDIA-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2025_07.csv
#
# Fetching NSE:COALINDIA-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2025_08.csv
#
# Fetching NSE:COALINDIA-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2025_09.csv
#
# Fetching NSE:COALINDIA-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2025_10.csv
#
# Fetching NSE:COALINDIA-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/coalindia_eq\coalindia_eq_2025_11.csv
#
# Fetching NSE:DIVISLAB-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/divislab_eq\divislab_eq_2024_12.csv
#
# Fetching NSE:DIVISLAB-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/divislab_eq\divislab_eq_2025_01.csv
#
# Fetching NSE:DIVISLAB-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/divislab_eq\divislab_eq_2025_02.csv
#
# Fetching NSE:DIVISLAB-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/divislab_eq\divislab_eq_2025_03.csv
#
# Fetching NSE:DIVISLAB-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/divislab_eq\divislab_eq_2025_04.csv
#
# Fetching NSE:DIVISLAB-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/divislab_eq\divislab_eq_2025_05.csv
#
# Fetching NSE:DIVISLAB-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/divislab_eq\divislab_eq_2025_06.csv
#
# Fetching NSE:DIVISLAB-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/divislab_eq\divislab_eq_2025_07.csv
#
# Fetching NSE:DIVISLAB-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/divislab_eq\divislab_eq_2025_08.csv
#
# Fetching NSE:DIVISLAB-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/divislab_eq\divislab_eq_2025_09.csv
#
# Fetching NSE:DIVISLAB-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/divislab_eq\divislab_eq_2025_10.csv
#
# Fetching NSE:DIVISLAB-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/divislab_eq\divislab_eq_2025_11.csv
#
# Fetching NSE:DRREDDY-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2024_12.csv
#
# Fetching NSE:DRREDDY-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2025_01.csv
#
# Fetching NSE:DRREDDY-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2025_02.csv
#
# Fetching NSE:DRREDDY-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2025_03.csv
#
# Fetching NSE:DRREDDY-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2025_04.csv
#
# Fetching NSE:DRREDDY-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2025_05.csv
#
# Fetching NSE:DRREDDY-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2025_06.csv
#
# Fetching NSE:DRREDDY-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2025_07.csv
#
# Fetching NSE:DRREDDY-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2025_08.csv
#
# Fetching NSE:DRREDDY-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2025_09.csv
#
# Fetching NSE:DRREDDY-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2025_10.csv
#
# Fetching NSE:DRREDDY-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/drreddy_eq\drreddy_eq_2025_11.csv
#
# Fetching NSE:EICHERMOT-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2024_12.csv
#
# Fetching NSE:EICHERMOT-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2025_01.csv
#
# Fetching NSE:EICHERMOT-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2025_02.csv
#
# Fetching NSE:EICHERMOT-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2025_03.csv
#
# Fetching NSE:EICHERMOT-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2025_04.csv
#
# Fetching NSE:EICHERMOT-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2025_05.csv
#
# Fetching NSE:EICHERMOT-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2025_06.csv
#
# Fetching NSE:EICHERMOT-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2025_07.csv
#
# Fetching NSE:EICHERMOT-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2025_08.csv
#
# Fetching NSE:EICHERMOT-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2025_09.csv
#
# Fetching NSE:EICHERMOT-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2025_10.csv
#
# Fetching NSE:EICHERMOT-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/eichermot_eq\eichermot_eq_2025_11.csv
#
# Fetching NSE:GRASIM-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/grasim_eq\grasim_eq_2024_12.csv
#
# Fetching NSE:GRASIM-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/grasim_eq\grasim_eq_2025_01.csv
#
# Fetching NSE:GRASIM-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/grasim_eq\grasim_eq_2025_02.csv
#
# Fetching NSE:GRASIM-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/grasim_eq\grasim_eq_2025_03.csv
#
# Fetching NSE:GRASIM-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/grasim_eq\grasim_eq_2025_04.csv
#
# Fetching NSE:GRASIM-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/grasim_eq\grasim_eq_2025_05.csv
#
# Fetching NSE:GRASIM-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/grasim_eq\grasim_eq_2025_06.csv
#
# Fetching NSE:GRASIM-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/grasim_eq\grasim_eq_2025_07.csv
#
# Fetching NSE:GRASIM-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/grasim_eq\grasim_eq_2025_08.csv
#
# Fetching NSE:GRASIM-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/grasim_eq\grasim_eq_2025_09.csv
#
# Fetching NSE:GRASIM-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/grasim_eq\grasim_eq_2025_10.csv
#
# Fetching NSE:GRASIM-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/grasim_eq\grasim_eq_2025_11.csv
#
# Fetching NSE:HCLTECH-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2024_12.csv
#
# Fetching NSE:HCLTECH-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2025_01.csv
#
# Fetching NSE:HCLTECH-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2025_02.csv
#
# Fetching NSE:HCLTECH-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2025_03.csv
#
# Fetching NSE:HCLTECH-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2025_04.csv
#
# Fetching NSE:HCLTECH-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2025_05.csv
#
# Fetching NSE:HCLTECH-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2025_06.csv
#
# Fetching NSE:HCLTECH-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2025_07.csv
#
# Fetching NSE:HCLTECH-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2025_08.csv
#
# Fetching NSE:HCLTECH-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2025_09.csv
#
# Fetching NSE:HCLTECH-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2025_10.csv
#
# Fetching NSE:HCLTECH-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/hcltech_eq\hcltech_eq_2025_11.csv
#
# Fetching NSE:HDFCBANK-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2024_12.csv
#
# Fetching NSE:HDFCBANK-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2025_01.csv
#
# Fetching NSE:HDFCBANK-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2025_02.csv
#
# Fetching NSE:HDFCBANK-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2025_03.csv
#
# Fetching NSE:HDFCBANK-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2025_04.csv
#
# Fetching NSE:HDFCBANK-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2025_05.csv
#
# Fetching NSE:HDFCBANK-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2025_06.csv
#
# Fetching NSE:HDFCBANK-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2025_07.csv
#
# Fetching NSE:HDFCBANK-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2025_08.csv
#
# Fetching NSE:HDFCBANK-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2025_09.csv
#
# Fetching NSE:HDFCBANK-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2025_10.csv
#
# Fetching NSE:HDFCBANK-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/hdfcbank_eq\hdfcbank_eq_2025_11.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2024_12.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2025_01.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2025_02.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2025_03.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2025_04.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2025_05.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2025_06.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2025_07.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2025_08.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2025_09.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2025_10.csv
#
# Fetching NSE:HDFCLIFE-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/hdfclife_eq\hdfclife_eq_2025_11.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2024_12.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2025_01.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2025_02.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2025_03.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2025_04.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2025_05.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2025_06.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2025_07.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2025_08.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2025_09.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2025_10.csv
#
# Fetching NSE:HEROMOTOCO-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/heromotoco_eq\heromotoco_eq_2025_11.csv
#
# Fetching NSE:HINDALCO-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2024_12.csv
#
# Fetching NSE:HINDALCO-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2025_01.csv
#
# Fetching NSE:HINDALCO-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2025_02.csv
#
# Fetching NSE:HINDALCO-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2025_03.csv
#
# Fetching NSE:HINDALCO-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2025_04.csv
#
# Fetching NSE:HINDALCO-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2025_05.csv
#
# Fetching NSE:HINDALCO-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2025_06.csv
#
# Fetching NSE:HINDALCO-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2025_07.csv
#
# Fetching NSE:HINDALCO-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2025_08.csv
#
# Fetching NSE:HINDALCO-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2025_09.csv
#
# Fetching NSE:HINDALCO-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2025_10.csv
#
# Fetching NSE:HINDALCO-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/hindalco_eq\hindalco_eq_2025_11.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2024_12.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2025_01.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2025_02.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2025_03.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2025_04.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2025_05.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2025_06.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2025_07.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2025_08.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2025_09.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2025_10.csv
#
# Fetching NSE:HINDUNILVR-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/hindunilvr_eq\hindunilvr_eq_2025_11.csv
#
# Fetching NSE:ICICIBANK-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2024_12.csv
#
# Fetching NSE:ICICIBANK-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2025_01.csv
#
# Fetching NSE:ICICIBANK-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2025_02.csv
#
# Fetching NSE:ICICIBANK-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2025_03.csv
#
# Fetching NSE:ICICIBANK-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2025_04.csv
#
# Fetching NSE:ICICIBANK-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2025_05.csv
#
# Fetching NSE:ICICIBANK-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2025_06.csv
#
# Fetching NSE:ICICIBANK-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2025_07.csv
#
# Fetching NSE:ICICIBANK-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2025_08.csv
#
# Fetching NSE:ICICIBANK-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2025_09.csv
#
# Fetching NSE:ICICIBANK-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2025_10.csv
#
# Fetching NSE:ICICIBANK-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/icicibank_eq\icicibank_eq_2025_11.csv
#
# Fetching NSE:ITC-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/itc_eq\itc_eq_2024_12.csv
#
# Fetching NSE:ITC-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/itc_eq\itc_eq_2025_01.csv
#
# Fetching NSE:ITC-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/itc_eq\itc_eq_2025_02.csv
#
# Fetching NSE:ITC-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/itc_eq\itc_eq_2025_03.csv
#
# Fetching NSE:ITC-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/itc_eq\itc_eq_2025_04.csv
#
# Fetching NSE:ITC-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/itc_eq\itc_eq_2025_05.csv
#
# Fetching NSE:ITC-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/itc_eq\itc_eq_2025_06.csv
#
# Fetching NSE:ITC-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/itc_eq\itc_eq_2025_07.csv
#
# Fetching NSE:ITC-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/itc_eq\itc_eq_2025_08.csv
#
# Fetching NSE:ITC-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/itc_eq\itc_eq_2025_09.csv
#
# Fetching NSE:ITC-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/itc_eq\itc_eq_2025_10.csv
#
# Fetching NSE:ITC-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/itc_eq\itc_eq_2025_11.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2024_12.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2025_01.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2025_02.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2025_03.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2025_04.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2025_05.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2025_06.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2025_07.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2025_08.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2025_09.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2025_10.csv
#
# Fetching NSE:INDUSINDBK-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/indusindbk_eq\indusindbk_eq_2025_11.csv
#
# Fetching NSE:INFY-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/infy_eq\infy_eq_2024_12.csv
#
# Fetching NSE:INFY-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/infy_eq\infy_eq_2025_01.csv
#
# Fetching NSE:INFY-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/infy_eq\infy_eq_2025_02.csv
#
# Fetching NSE:INFY-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/infy_eq\infy_eq_2025_03.csv
#
# Fetching NSE:INFY-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/infy_eq\infy_eq_2025_04.csv
#
# Fetching NSE:INFY-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/infy_eq\infy_eq_2025_05.csv
#
# Fetching NSE:INFY-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/infy_eq\infy_eq_2025_06.csv
#
# Fetching NSE:INFY-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/infy_eq\infy_eq_2025_07.csv
#
# Fetching NSE:INFY-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/infy_eq\infy_eq_2025_08.csv
#
# Fetching NSE:INFY-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/infy_eq\infy_eq_2025_09.csv
#
# Fetching NSE:INFY-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/infy_eq\infy_eq_2025_10.csv
#
# Fetching NSE:INFY-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/infy_eq\infy_eq_2025_11.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2024_12.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2025_01.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2025_02.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2025_03.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2025_04.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2025_05.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2025_06.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2025_07.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2025_08.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2025_09.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2025_10.csv
#
# Fetching NSE:JSWSTEEL-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/jswsteel_eq\jswsteel_eq_2025_11.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2024_12.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2025_01.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2025_02.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2025_03.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2025_04.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2025_05.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2025_06.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2025_07.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2025_08.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2025_09.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2025_10.csv
#
# Fetching NSE:KOTAKBANK-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/kotakbank_eq\kotakbank_eq_2025_11.csv
#
# Fetching NSE:LT-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/lt_eq\lt_eq_2024_12.csv
#
# Fetching NSE:LT-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/lt_eq\lt_eq_2025_01.csv
#
# Fetching NSE:LT-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/lt_eq\lt_eq_2025_02.csv
#
# Fetching NSE:LT-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/lt_eq\lt_eq_2025_03.csv
#
# Fetching NSE:LT-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/lt_eq\lt_eq_2025_04.csv
#
# Fetching NSE:LT-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/lt_eq\lt_eq_2025_05.csv
#
# Fetching NSE:LT-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/lt_eq\lt_eq_2025_06.csv
#
# Fetching NSE:LT-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/lt_eq\lt_eq_2025_07.csv
#
# Fetching NSE:LT-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/lt_eq\lt_eq_2025_08.csv
#
# Fetching NSE:LT-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/lt_eq\lt_eq_2025_09.csv
#
# Fetching NSE:LT-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/lt_eq\lt_eq_2025_10.csv
#
# Fetching NSE:LT-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/lt_eq\lt_eq_2025_11.csv
#
# Fetching NSE:M&M-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/m&m_eq\m&m_eq_2024_12.csv
#
# Fetching NSE:M&M-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/m&m_eq\m&m_eq_2025_01.csv
#
# Fetching NSE:M&M-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/m&m_eq\m&m_eq_2025_02.csv
#
# Fetching NSE:M&M-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/m&m_eq\m&m_eq_2025_03.csv
#
# Fetching NSE:M&M-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/m&m_eq\m&m_eq_2025_04.csv
#
# Fetching NSE:M&M-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/m&m_eq\m&m_eq_2025_05.csv
#
# Fetching NSE:M&M-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/m&m_eq\m&m_eq_2025_06.csv
#
# Fetching NSE:M&M-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/m&m_eq\m&m_eq_2025_07.csv
#
# Fetching NSE:M&M-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/m&m_eq\m&m_eq_2025_08.csv
#
# Fetching NSE:M&M-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/m&m_eq\m&m_eq_2025_09.csv
#
# Fetching NSE:M&M-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/m&m_eq\m&m_eq_2025_10.csv
#
# Fetching NSE:M&M-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/m&m_eq\m&m_eq_2025_11.csv
#
# Fetching NSE:MARUTI-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/maruti_eq\maruti_eq_2024_12.csv
#
# Fetching NSE:MARUTI-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/maruti_eq\maruti_eq_2025_01.csv
#
# Fetching NSE:MARUTI-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/maruti_eq\maruti_eq_2025_02.csv
#
# Fetching NSE:MARUTI-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/maruti_eq\maruti_eq_2025_03.csv
#
# Fetching NSE:MARUTI-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/maruti_eq\maruti_eq_2025_04.csv
#
# Fetching NSE:MARUTI-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/maruti_eq\maruti_eq_2025_05.csv
#
# Fetching NSE:MARUTI-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/maruti_eq\maruti_eq_2025_06.csv
#
# Fetching NSE:MARUTI-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/maruti_eq\maruti_eq_2025_07.csv
#
# Fetching NSE:MARUTI-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/maruti_eq\maruti_eq_2025_08.csv
#
# Fetching NSE:MARUTI-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/maruti_eq\maruti_eq_2025_09.csv
#
# Fetching NSE:MARUTI-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/maruti_eq\maruti_eq_2025_10.csv
#
# Fetching NSE:MARUTI-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/maruti_eq\maruti_eq_2025_11.csv
#
# Fetching NSE:NTPC-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2024_12.csv
#
# Fetching NSE:NTPC-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2025_01.csv
#
# Fetching NSE:NTPC-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2025_02.csv
#
# Fetching NSE:NTPC-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2025_03.csv
#
# Fetching NSE:NTPC-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2025_04.csv
#
# Fetching NSE:NTPC-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2025_05.csv
#
# Fetching NSE:NTPC-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2025_06.csv
#
# Fetching NSE:NTPC-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2025_07.csv
#
# Fetching NSE:NTPC-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2025_08.csv
#
# Fetching NSE:NTPC-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2025_09.csv
#
# Fetching NSE:NTPC-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2025_10.csv
#
# Fetching NSE:NTPC-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/ntpc_eq\ntpc_eq_2025_11.csv
#
# Fetching NSE:NESTLEIND-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2024_12.csv
#
# Fetching NSE:NESTLEIND-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2025_01.csv
#
# Fetching NSE:NESTLEIND-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2025_02.csv
#
# Fetching NSE:NESTLEIND-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2025_03.csv
#
# Fetching NSE:NESTLEIND-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2025_04.csv
#
# Fetching NSE:NESTLEIND-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2025_05.csv
#
# Fetching NSE:NESTLEIND-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2025_06.csv
#
# Fetching NSE:NESTLEIND-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2025_07.csv
#
# Fetching NSE:NESTLEIND-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2025_08.csv
#
# Fetching NSE:NESTLEIND-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2025_09.csv
#
# Fetching NSE:NESTLEIND-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2025_10.csv
#
# Fetching NSE:NESTLEIND-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/nestleind_eq\nestleind_eq_2025_11.csv
#
# Fetching NSE:ONGC-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/ongc_eq\ongc_eq_2024_12.csv
#
# Fetching NSE:ONGC-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/ongc_eq\ongc_eq_2025_01.csv
#
# Fetching NSE:ONGC-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/ongc_eq\ongc_eq_2025_02.csv
#
# Fetching NSE:ONGC-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/ongc_eq\ongc_eq_2025_03.csv
#
# Fetching NSE:ONGC-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/ongc_eq\ongc_eq_2025_04.csv
#
# Fetching NSE:ONGC-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/ongc_eq\ongc_eq_2025_05.csv
#
# Fetching NSE:ONGC-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/ongc_eq\ongc_eq_2025_06.csv
#
# Fetching NSE:ONGC-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/ongc_eq\ongc_eq_2025_07.csv
#
# Fetching NSE:ONGC-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/ongc_eq\ongc_eq_2025_08.csv
#
# Fetching NSE:ONGC-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/ongc_eq\ongc_eq_2025_09.csv
#
# Fetching NSE:ONGC-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/ongc_eq\ongc_eq_2025_10.csv
#
# Fetching NSE:ONGC-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/ongc_eq\ongc_eq_2025_11.csv
#
# Fetching NSE:POWERGRID-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2024_12.csv
#
# Fetching NSE:POWERGRID-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2025_01.csv
#
# Fetching NSE:POWERGRID-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2025_02.csv
#
# Fetching NSE:POWERGRID-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2025_03.csv
#
# Fetching NSE:POWERGRID-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2025_04.csv
#
# Fetching NSE:POWERGRID-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2025_05.csv
#
# Fetching NSE:POWERGRID-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2025_06.csv
#
# Fetching NSE:POWERGRID-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2025_07.csv
#
# Fetching NSE:POWERGRID-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2025_08.csv
#
# Fetching NSE:POWERGRID-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2025_09.csv
#
# Fetching NSE:POWERGRID-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2025_10.csv
#
# Fetching NSE:POWERGRID-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/powergrid_eq\powergrid_eq_2025_11.csv
#
# Fetching NSE:RELIANCE-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/reliance_eq\reliance_eq_2024_12.csv
#
# Fetching NSE:RELIANCE-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/reliance_eq\reliance_eq_2025_01.csv
#
# Fetching NSE:RELIANCE-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/reliance_eq\reliance_eq_2025_02.csv
#
# Fetching NSE:RELIANCE-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/reliance_eq\reliance_eq_2025_03.csv
#
# Fetching NSE:RELIANCE-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/reliance_eq\reliance_eq_2025_04.csv
#
# Fetching NSE:RELIANCE-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/reliance_eq\reliance_eq_2025_05.csv
#
# Fetching NSE:RELIANCE-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/reliance_eq\reliance_eq_2025_06.csv
#
# Fetching NSE:RELIANCE-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/reliance_eq\reliance_eq_2025_07.csv
#
# Fetching NSE:RELIANCE-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/reliance_eq\reliance_eq_2025_08.csv
#
# Fetching NSE:RELIANCE-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/reliance_eq\reliance_eq_2025_09.csv
#
# Fetching NSE:RELIANCE-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/reliance_eq\reliance_eq_2025_10.csv
#
# Fetching NSE:RELIANCE-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/reliance_eq\reliance_eq_2025_11.csv
#
# Fetching NSE:SBILIFE-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2024_12.csv
#
# Fetching NSE:SBILIFE-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2025_01.csv
#
# Fetching NSE:SBILIFE-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2025_02.csv
#
# Fetching NSE:SBILIFE-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2025_03.csv
#
# Fetching NSE:SBILIFE-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2025_04.csv
#
# Fetching NSE:SBILIFE-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2025_05.csv
#
# Fetching NSE:SBILIFE-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2025_06.csv
#
# Fetching NSE:SBILIFE-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2025_07.csv
#
# Fetching NSE:SBILIFE-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2025_08.csv
#
# Fetching NSE:SBILIFE-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2025_09.csv
#
# Fetching NSE:SBILIFE-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2025_10.csv
#
# Fetching NSE:SBILIFE-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/sbilife_eq\sbilife_eq_2025_11.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2024_12.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2025_01.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2025_02.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2025_03.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2025_04.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2025_05.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2025_06.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2025_07.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2025_08.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2025_09.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2025_10.csv
#
# Fetching NSE:SHRIRAMFIN-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/shriramfin_eq\shriramfin_eq_2025_11.csv
#
# Fetching NSE:SBIN-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/sbin_eq\sbin_eq_2024_12.csv
#
# Fetching NSE:SBIN-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/sbin_eq\sbin_eq_2025_01.csv
#
# Fetching NSE:SBIN-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/sbin_eq\sbin_eq_2025_02.csv
#
# Fetching NSE:SBIN-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/sbin_eq\sbin_eq_2025_03.csv
#
# Fetching NSE:SBIN-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/sbin_eq\sbin_eq_2025_04.csv
#
# Fetching NSE:SBIN-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/sbin_eq\sbin_eq_2025_05.csv
#
# Fetching NSE:SBIN-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/sbin_eq\sbin_eq_2025_06.csv
#
# Fetching NSE:SBIN-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/sbin_eq\sbin_eq_2025_07.csv
#
# Fetching NSE:SBIN-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/sbin_eq\sbin_eq_2025_08.csv
#
# Fetching NSE:SBIN-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/sbin_eq\sbin_eq_2025_09.csv
#
# Fetching NSE:SBIN-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/sbin_eq\sbin_eq_2025_10.csv
#
# Fetching NSE:SBIN-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/sbin_eq\sbin_eq_2025_11.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2024_12.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2025_01.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2025_02.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2025_03.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2025_04.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2025_05.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2025_06.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2025_07.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2025_08.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2025_09.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2025_10.csv
#
# Fetching NSE:SUNPHARMA-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/sunpharma_eq\sunpharma_eq_2025_11.csv
#
# Fetching NSE:TCS-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/tcs_eq\tcs_eq_2024_12.csv
#
# Fetching NSE:TCS-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/tcs_eq\tcs_eq_2025_01.csv
#
# Fetching NSE:TCS-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/tcs_eq\tcs_eq_2025_02.csv
#
# Fetching NSE:TCS-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/tcs_eq\tcs_eq_2025_03.csv
#
# Fetching NSE:TCS-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/tcs_eq\tcs_eq_2025_04.csv
#
# Fetching NSE:TCS-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/tcs_eq\tcs_eq_2025_05.csv
#
# Fetching NSE:TCS-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/tcs_eq\tcs_eq_2025_06.csv
#
# Fetching NSE:TCS-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/tcs_eq\tcs_eq_2025_07.csv
#
# Fetching NSE:TCS-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/tcs_eq\tcs_eq_2025_08.csv
#
# Fetching NSE:TCS-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/tcs_eq\tcs_eq_2025_09.csv
#
# Fetching NSE:TCS-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/tcs_eq\tcs_eq_2025_10.csv
#
# Fetching NSE:TCS-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/tcs_eq\tcs_eq_2025_11.csv
#
# Fetching NSE:TATACONSUM-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2024_12.csv
#
# Fetching NSE:TATACONSUM-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2025_01.csv
#
# Fetching NSE:TATACONSUM-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2025_02.csv
#
# Fetching NSE:TATACONSUM-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2025_03.csv
#
# Fetching NSE:TATACONSUM-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2025_04.csv
#
# Fetching NSE:TATACONSUM-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2025_05.csv
#
# Fetching NSE:TATACONSUM-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2025_06.csv
#
# Fetching NSE:TATACONSUM-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2025_07.csv
#
# Fetching NSE:TATACONSUM-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2025_08.csv
#
# Fetching NSE:TATACONSUM-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2025_09.csv
#
# Fetching NSE:TATACONSUM-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2025_10.csv
#
# Fetching NSE:TATACONSUM-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/tataconsum_eq\tataconsum_eq_2025_11.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2024-12-01 → 2024-12-31
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2024_12.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2025-01-01 → 2025-01-31
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2025_01.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2025-02-01 → 2025-02-28
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2025_02.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2025-03-01 → 2025-03-31
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2025_03.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2025-04-01 → 2025-04-30
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2025_04.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2025-05-01 → 2025-05-31
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2025_05.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2025-06-01 → 2025-06-30
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2025_06.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2025-07-01 → 2025-07-31
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2025_07.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2025-08-01 → 2025-08-31
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2025_08.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2025-09-01 → 2025-09-30
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2025_09.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2025-10-01 → 2025-10-31
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2025_10.csv
#
# Fetching NSE:TATAMOTORS-EQ: 2025-11-01 → 2025-11-30
# No data: 5_min_data/tatamotors_eq\tatamotors_eq_2025_11.csv
#
# Fetching NSE:TATASTEEL-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2024_12.csv
#
# Fetching NSE:TATASTEEL-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2025_01.csv
#
# Fetching NSE:TATASTEEL-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2025_02.csv
#
# Fetching NSE:TATASTEEL-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2025_03.csv
#
# Fetching NSE:TATASTEEL-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2025_04.csv
#
# Fetching NSE:TATASTEEL-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2025_05.csv
#
# Fetching NSE:TATASTEEL-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2025_06.csv
#
# Fetching NSE:TATASTEEL-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2025_07.csv
#
# Fetching NSE:TATASTEEL-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2025_08.csv
#
# Fetching NSE:TATASTEEL-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2025_09.csv
#
# Fetching NSE:TATASTEEL-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2025_10.csv
#
# Fetching NSE:TATASTEEL-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/tatasteel_eq\tatasteel_eq_2025_11.csv
#
# Fetching NSE:TECHM-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/techm_eq\techm_eq_2024_12.csv
#
# Fetching NSE:TECHM-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/techm_eq\techm_eq_2025_01.csv
#
# Fetching NSE:TECHM-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/techm_eq\techm_eq_2025_02.csv
#
# Fetching NSE:TECHM-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/techm_eq\techm_eq_2025_03.csv
#
# Fetching NSE:TECHM-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/techm_eq\techm_eq_2025_04.csv
#
# Fetching NSE:TECHM-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/techm_eq\techm_eq_2025_05.csv
#
# Fetching NSE:TECHM-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/techm_eq\techm_eq_2025_06.csv
#
# Fetching NSE:TECHM-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/techm_eq\techm_eq_2025_07.csv
#
# Fetching NSE:TECHM-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/techm_eq\techm_eq_2025_08.csv
#
# Fetching NSE:TECHM-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/techm_eq\techm_eq_2025_09.csv
#
# Fetching NSE:TECHM-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/techm_eq\techm_eq_2025_10.csv
#
# Fetching NSE:TECHM-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/techm_eq\techm_eq_2025_11.csv
#
# Fetching NSE:TITAN-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/titan_eq\titan_eq_2024_12.csv
#
# Fetching NSE:TITAN-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/titan_eq\titan_eq_2025_01.csv
#
# Fetching NSE:TITAN-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/titan_eq\titan_eq_2025_02.csv
#
# Fetching NSE:TITAN-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/titan_eq\titan_eq_2025_03.csv
#
# Fetching NSE:TITAN-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/titan_eq\titan_eq_2025_04.csv
#
# Fetching NSE:TITAN-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/titan_eq\titan_eq_2025_05.csv
#
# Fetching NSE:TITAN-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/titan_eq\titan_eq_2025_06.csv
#
# Fetching NSE:TITAN-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/titan_eq\titan_eq_2025_07.csv
#
# Fetching NSE:TITAN-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/titan_eq\titan_eq_2025_08.csv
#
# Fetching NSE:TITAN-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/titan_eq\titan_eq_2025_09.csv
#
# Fetching NSE:TITAN-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/titan_eq\titan_eq_2025_10.csv
#
# Fetching NSE:TITAN-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/titan_eq\titan_eq_2025_11.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2024_12.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2025_01.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2025_02.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2025_03.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2025_04.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2025_05.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2025_06.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2025_07.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2025_08.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2025_09.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2025_10.csv
#
# Fetching NSE:ULTRACEMCO-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/ultracemco_eq\ultracemco_eq_2025_11.csv
#
# Fetching NSE:WIPRO-EQ: 2024-12-01 → 2024-12-31
# Saved: 5_min_data/wipro_eq\wipro_eq_2024_12.csv
#
# Fetching NSE:WIPRO-EQ: 2025-01-01 → 2025-01-31
# Saved: 5_min_data/wipro_eq\wipro_eq_2025_01.csv
#
# Fetching NSE:WIPRO-EQ: 2025-02-01 → 2025-02-28
# Saved: 5_min_data/wipro_eq\wipro_eq_2025_02.csv
#
# Fetching NSE:WIPRO-EQ: 2025-03-01 → 2025-03-31
# Saved: 5_min_data/wipro_eq\wipro_eq_2025_03.csv
#
# Fetching NSE:WIPRO-EQ: 2025-04-01 → 2025-04-30
# Saved: 5_min_data/wipro_eq\wipro_eq_2025_04.csv
#
# Fetching NSE:WIPRO-EQ: 2025-05-01 → 2025-05-31
# Saved: 5_min_data/wipro_eq\wipro_eq_2025_05.csv
#
# Fetching NSE:WIPRO-EQ: 2025-06-01 → 2025-06-30
# Saved: 5_min_data/wipro_eq\wipro_eq_2025_06.csv
#
# Fetching NSE:WIPRO-EQ: 2025-07-01 → 2025-07-31
# Saved: 5_min_data/wipro_eq\wipro_eq_2025_07.csv
#
# Fetching NSE:WIPRO-EQ: 2025-08-01 → 2025-08-31
# Saved: 5_min_data/wipro_eq\wipro_eq_2025_08.csv
#
# Fetching NSE:WIPRO-EQ: 2025-09-01 → 2025-09-30
# Saved: 5_min_data/wipro_eq\wipro_eq_2025_09.csv
#
# Fetching NSE:WIPRO-EQ: 2025-10-01 → 2025-10-31
# Saved: 5_min_data/wipro_eq\wipro_eq_2025_10.csv
#
# Fetching NSE:WIPRO-EQ: 2025-11-01 → 2025-11-30
# Saved: 5_min_data/wipro_eq\wipro_eq_2025_11.csv
#
# Fetching NSE:ZOMATO-EQ: 2024-12-01 → 2024-12-31
# No data: 5_min_data/zomato_eq\zomato_eq_2024_12.csv
#
# Fetching NSE:ZOMATO-EQ: 2025-01-01 → 2025-01-31
# No data: 5_min_data/zomato_eq\zomato_eq_2025_01.csv
#
# Fetching NSE:ZOMATO-EQ: 2025-02-01 → 2025-02-28
# No data: 5_min_data/zomato_eq\zomato_eq_2025_02.csv
#
# Fetching NSE:ZOMATO-EQ: 2025-03-01 → 2025-03-31
# No data: 5_min_data/zomato_eq\zomato_eq_2025_03.csv
#
# Fetching NSE:ZOMATO-EQ: 2025-04-01 → 2025-04-30
# No data: 5_min_data/zomato_eq\zomato_eq_2025_04.csv
#
# Fetching NSE:ZOMATO-EQ: 2025-05-01 → 2025-05-31
# No data: 5_min_data/zomato_eq\zomato_eq_2025_05.csv
#
# Fetching NSE:ZOMATO-EQ: 2025-06-01 → 2025-06-30
# No data: 5_min_data/zomato_eq\zomato_eq_2025_06.csv
#
# Fetching NSE:ZOMATO-EQ: 2025-07-01 → 2025-07-31
# No data: 5_min_data/zomato_eq\zomato_eq_2025_07.csv
#
# Fetching NSE:ZOMATO-EQ: 2025-08-01 → 2025-08-31
# No data: 5_min_data/zomato_eq\zomato_eq_2025_08.csv
#
# Fetching NSE:ZOMATO-EQ: 2025-09-01 → 2025-09-30
# No data: 5_min_data/zomato_eq\zomato_eq_2025_09.csv
#
# Fetching NSE:ZOMATO-EQ: 2025-10-01 → 2025-10-31
# No data: 5_min_data/zomato_eq\zomato_eq_2025_10.csv
#
# Fetching NSE:ZOMATO-EQ: 2025-11-01 → 2025-11-30
# No data: 5_min_data/zomato_eq\zomato_eq_2025_11.csv
